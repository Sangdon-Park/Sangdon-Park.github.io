# %% [markdown]
# # [1주차 과제] K-최근접 이웃으로 과일 분류하기
#
# **과목**: 머신러닝
# **참고**: 혼자 공부하는 머신러닝+딥러닝 1-3장
#
# ---
#
# ### 📌 과제 안내
# - 각 문제의 `# YOUR CODE HERE` 부분에 코드를 작성하세요.
# - `raise NotImplementedError()`는 반드시 **삭제**하고 코드를 작성하세요.
# - **변수명**을 정확히 지켜주세요. 자동 채점에 사용됩니다.
# - 제출: 이 파일을 GitHub 레포지토리에 push하면 자동 채점됩니다.

# %% [markdown]
# ---
# ## 배경
#
# 과일 판매점에서 사과(apple)와 귤(mandarin)을 자동으로 분류하는 시스템을 만들려고 합니다.
# 각 과일의 **무게(g)**와 **당도(brix)**를 측정한 데이터가 아래에 주어져 있습니다.
#
# - 사과: 30개 (무게 150~300g, 당도 11~15 brix)
# - 귤: 20개 (무게 50~120g, 당도 8~14 brix)
#
# 이 데이터를 사용하여 K-최근접 이웃(KNN) 분류 모델을 학습하고, 새로운 과일을 분류해 봅시다.

# %% [markdown]
# ---
# ## 문제 0: 데이터 준비 (배점: 10점)
#
# 아래 사과와 귤 데이터를 합쳐서 머신러닝 모델에 입력할 수 있는 형태로 만드세요.
#
# **요구사항:**
# 1. `weight` : 사과 무게 + 귤 무게를 합친 리스트
# 2. `sugar` : 사과 당도 + 귤 당도를 합친 리스트
# 3. `fruit_data` : `[[무게, 당도], [무게, 당도], ...]` 형태의 2차원 리스트
# 4. `fruit_target` : 사과는 1, 귤은 0으로 라벨링한 리스트 (사과 30개, 귤 20개)

# %%
# 사과 데이터 (수정하지 마세요)
apple_weight = [151.0, 153.8, 154.0, 154.5, 163.0, 163.9, 164.5, 173.3, 179.8, 182.8,
                183.1, 183.5, 191.3, 200.5, 201.0, 213.3, 225.8, 231.7, 238.4, 240.6,
                245.9, 247.5, 251.5, 254.7, 260.5, 270.9, 271.4, 277.1, 283.8, 293.6]
apple_sugar = [14.2, 13.9, 13.1, 14.9, 12.5, 13.2, 14.3, 13.5, 14.4, 13.3,
               13.8, 11.2, 11.9, 12.2, 11.3, 11.9, 11.4, 12.1, 13.5, 12.5,
               12.5, 11.8, 12.1, 14.7, 13.6, 13.4, 11.7, 13.9, 11.7, 12.5]

# 귤 데이터 (수정하지 마세요)
mandarin_weight = [52.2, 64.8, 66.0, 67.3, 68.5, 68.7, 72.0, 72.1, 77.7, 82.1,
                   89.0, 94.8, 95.9, 97.9, 104.3, 109.0, 111.3, 114.0, 116.0, 119.3]
mandarin_sugar = [11.4, 9.6, 11.5, 13.4, 10.4, 9.3, 14.0, 11.1, 8.5, 8.3,
                  8.7, 11.8, 12.8, 10.5, 8.4, 10.3, 14.0, 11.2, 13.8, 13.2]

# %%
# 문제 0: 데이터 합치기

# 1. weight: 사과 무게와 귤 무게를 합친 리스트
# YOUR CODE HERE
raise NotImplementedError()

# 2. sugar: 사과 당도와 귤 당도를 합친 리스트
# YOUR CODE HERE
raise NotImplementedError()

# 3. fruit_data: [[무게, 당도], ...] 형태의 2차원 리스트
# YOUR CODE HERE
raise NotImplementedError()

# 4. fruit_target: 사과=1 (30개), 귤=0 (20개)
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ---
# ## 문제 1: KNN 모델 훈련 (배점: 20점)
#
# scikit-learn의 `KNeighborsClassifier`를 사용하여 모델을 훈련하세요.
#
# **요구사항:**
# 1. `kn` : 기본 매개변수(n_neighbors=5)로 KNeighborsClassifier 객체를 생성하세요.
# 2. `fruit_data`와 `fruit_target`으로 모델을 훈련(fit)하세요.
# 3. `train_score` : 훈련 데이터에 대한 정확도(score)를 저장하세요.

# %%
from sklearn.neighbors import KNeighborsClassifier

# 문제 1: KNN 모델 훈련

# 1. KNeighborsClassifier 객체 생성 (기본 매개변수)
# YOUR CODE HERE
raise NotImplementedError()

# 2. 모델 훈련 (fit)
# YOUR CODE HERE
raise NotImplementedError()

# 3. 훈련 정확도 저장
# YOUR CODE HERE
raise NotImplementedError()

print(f'훈련 정확도: {train_score}')

# %% [markdown]
# ---
# ## 문제 2: 새로운 데이터 예측 (배점: 20점)
#
# 훈련된 모델을 사용하여 새로운 과일의 종류를 예측하세요.
#
# **요구사항:**
# 1. `pred_apple` : 무게 200g, 당도 13인 과일의 예측 결과 (predict 사용)
# 2. `pred_mandarin` : 무게 80g, 당도 10인 과일의 예측 결과

# %%
# 문제 2: 새로운 데이터 예측

# 1. 무게 200, 당도 13인 과일 예측
# YOUR CODE HERE
raise NotImplementedError()

# 2. 무게 80, 당도 10인 과일 예측
# YOUR CODE HERE
raise NotImplementedError()

print(f'[200, 13] 예측 결과: {pred_apple}')
print(f'[80, 10] 예측 결과: {pred_mandarin}')

# %% [markdown]
# ---
# ## 문제 3: n_neighbors 변경 실험 (배점: 25점)
#
# 전체 데이터 개수(50개)를 `n_neighbors`로 설정한 KNN 모델을 만들고, 정확도를 확인하세요.
# 이 경우 모든 데이터를 참고하므로 항상 다수결(사과 30개 > 귤 20개)로 사과를 예측하게 됩니다.
#
# **요구사항:**
# 1. `kn50` : n_neighbors=50으로 KNeighborsClassifier 객체를 생성하세요.
# 2. `fruit_data`와 `fruit_target`으로 모델을 훈련하세요.
# 3. `score_50` : 훈련 데이터에 대한 정확도를 저장하세요.
# 4. `expected_score` : 전체 50개 중 사과(30개)의 비율을 계산하여 저장하세요. (30/50)

# %%
# 문제 3: n_neighbors=50 실험

# 1. n_neighbors=50으로 모델 생성
# YOUR CODE HERE
raise NotImplementedError()

# 2. 모델 훈련
# YOUR CODE HERE
raise NotImplementedError()

# 3. 정확도 저장
# YOUR CODE HERE
raise NotImplementedError()

# 4. 예상 정확도 계산 (30/50)
# YOUR CODE HERE
raise NotImplementedError()

print(f'n_neighbors=50 정확도: {score_50}')
print(f'예상 정확도 (30/50): {expected_score}')

# %% [markdown]
# ---
# ## 문제 4: 최적의 n_neighbors 찾기 (배점: 25점)
#
# n_neighbors를 5부터 49까지 변경하면서 정확도가 1.0(100%)에서 처음으로 떨어지는 n_neighbors 값을 찾으세요.
#
# **요구사항:**
# 1. `first_drop_n` : 정확도가 처음으로 1.0 미만이 되는 n_neighbors 값
# 2. `first_drop_score` : 그때의 정확도 값
#
# **힌트**: for 반복문과 `kn.n_neighbors` 속성을 활용하세요.

# %%
# 문제 4: 최적의 n_neighbors 찾기

# kn 모델을 다시 기본값으로 생성하고 훈련
kn = KNeighborsClassifier()
kn.fit(fruit_data, fruit_target)

# n_neighbors를 5~49까지 변경하며 처음으로 정확도가 1.0 미만인 값 찾기
first_drop_n = None
first_drop_score = None

# YOUR CODE HERE
raise NotImplementedError()

print(f'처음 정확도가 떨어지는 n_neighbors: {first_drop_n}')
print(f'그때의 정확도: {first_drop_score}')

# %% [markdown]
# ---
# ## 📊 시각화 (채점 대상 아님)
#
# 아래 코드를 실행하여 데이터와 예측 결과를 시각화해보세요.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.scatter(apple_weight, apple_sugar, label='Apple', color='red', alpha=0.7)
plt.scatter(mandarin_weight, mandarin_sugar, label='Mandarin', color='orange', alpha=0.7)
plt.scatter(200, 13, marker='^', color='darkred', s=150, label='New (200, 13)', zorder=5)
plt.scatter(80, 10, marker='s', color='darkorange', s=150, label='New (80, 10)', zorder=5)
plt.xlabel('Weight (g)')
plt.ylabel('Sugar (brix)')
plt.legend()
plt.title('Fruit Classification - KNN')
plt.grid(True, alpha=0.3)
plt.show()
